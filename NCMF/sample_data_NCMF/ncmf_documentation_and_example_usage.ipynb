# %% [markdown]
# ## NCMF
# Example of running the "NCMF" module

# %% [markdown]
# #### *User inputs*

# %%
sample_no = 1
data_dir = f"./"
dataset_name = "sample"

# %%
! mkdir -p {data_dir}/{dataset_name}/{sample_no}

# %% [markdown]
# #### *Loading all necessary modules*

# %%
import sys
sys.path.append("..")

# %%
import pprint
import numpy as np
import pickle as pkl
import time
import itertools
import os
import pprint

# %%
from src.ncmf import ncmf

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
import torch

# %%
pp = pprint.PrettyPrinter()

# %% [markdown]
# #### *Instantiating the NCMF model with the specified hyper-parameters*

# %%
# Setting hyperparameters
num_epochs = 100
batch_size = 2048
weight_decay = 0.5
learning_rate = 1e-6
convergence_threshold = -1e-3
entity_matrices = ['X0', 'X1'] 
matrix_types = {
    "real": ["X0"],
    "binary": ["X1"]
}

# %%
ncmf_model = ncmf(sample_no, data_dir, dataset_name, matrix_types, num_epochs, learning_rate, weight_decay, convergence_threshold, batch_size, batch_size, entity_matrices, autoencoder_act_f = "tanh", reconstructor_act_f = "tanh")

# %% [markdown]
# #### *Fitting... *
# - Performs the input transformation and network construction
# - (Pre-trains and) trains the model to obtain the entity representations
# - Reconstruct the input matrices using the entity representations obtained

# %%
ncmf_model.fit()
# Out:
# Mapping node ids to matrix indices...
# Splitting training and validation links...
# 16000
# Loading matrices and masks...
# Warning: Last batch has 200 rows, while other batch sizes are 2048.
# Warning: Last batch has 400 rows, while other batch sizes are 2048.
# Warning: Last batch has 200 rows, while other batch sizes are 2048.
# Warning: Last batch has 400 rows, while other batch sizes are 2048.
# To reconstruct X0
# dim:0; e0
# X0 e0 row
# X1 e0 row
# dim:1; e1
# X0 e1 col
# To reconstruct X1
# dim:0; e0
# X0 e0 row
# X1 e0 row
# dim:1; e2
# X1 e2 col
# Preparing autoencoders' configurations...
# Preparing reconstructors' configurations...
# Preparing fusions' configurations...
# Initialising autoencoders...
# Initialising reconstructors...
# Initialising fusions...
# ZINORM
# ZINB
# Retreive Embedding
# ZINORM
# ZINB
# ====> Epoch 0: Average Train Loss: 5.5438229 | Train RMSE: 1.5791374 | Average Valid Loss: 1.5021803 | Valid RMSE: 1.5768486 | beta: 0.0
# ZINORM
# ZINB
# Retreive Embedding
# ZINORM
# ZINB
# ====> Epoch 1: Average Train Loss: 5.5473487 | Train RMSE: 1.5779821 | Average Valid Loss: 1.5018881 | Valid RMSE: 1.5760215 | beta: 0.01921471959676957
# ZINORM
# ZINB
# Retreive Embedding
# ZINORM
# ZINB
# ====> Epoch 2: Average Train Loss: 5.5469786 | Train RMSE: 1.5771222 | Average Valid Loss: 1.5017013 | Valid RMSE: 1.5754606 | beta: 0.07612046748871326
# ZINORM
# ZINB
# Retreive Embedding
# ZINORM
# ZINB
# ====> Epoch 3: Average Train Loss: 5.5535033 | Train RMSE: 1.5766131 | Average Valid Loss: 1.5016074 | Valid RMSE: 1.5751946 | beta: 0.16853038769745476
# ZINORM
# ZINB
# Retreive Embedding
# ZINORM
# ZINB
# ====> Epoch 4: Average Train Loss: 5.5570319 | Train RMSE: 1.5763986 | Average Valid Loss: 1.5015877 | Valid RMSE: 1.5751320 | beta: 0.2928932188134524
# ZINORM
# ZINB
# Retreive Embedding
# ZINORM
# ZINB
# ====> Epoch 5: Average Train Loss: 5.5658299 | Train RMSE: 1.5760250 | Average Valid Loss: 1.5012514 | Valid RMSE: 1.5741819 | beta: 0.4444297669803977
# ZINORM
# ZINB
# Retreive Embedding
# ZINORM
# ZINB
# ====> Epoch 6: Average Train Loss: 5.5768705 | Train RMSE: 1.5750272 | Average Valid Loss: 1.5009636 | Valid RMSE: 1.5733680 | beta: 0.6173165676349102
# ZINORM
# ZINB
# Retreive Embedding
# ZINORM
# ZINB
# ====> Epoch